# %%
import requests
from IPython.core.display import HTML

# %% [markdown]
# # Gaze estimation
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
# This is the first mandatory exercise which means you will have to hand in this Jupyter Notebook with your implementation and notes. This exercise is split into multiple parts which have to be submitted together. The submission deadline is available on LearnIT.
#
#
# </div>
#
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
#
# <article class="message">
#     <div class="message-body">
#         <strong>Overview of mandatory tasks</strong>
#         <ul style="list-style: none;">
#             <li>
#             <a href="#visualization">Task 1: Visualisation 1</a>
#             </li>
#             <li>
#             <a href="#visualisation2">Task 2: Visualisation 2</a>
#             </li>
#             <li>
#             <a href="#identify">Task 3: Identify the design matrix</a>
#             </li>
#             <li>
#             <a href="#task_model">Task 4: Implement a gaze model</a>
#             </li>
#             <li>
#             <a href="#evaluation">Task 5: Model evaluation</a>
#             </li>
#             <li>
#             <a href="#improvements">Task 6: Model improvements</a>
#             </li>
#             <li>
#             <a href="#glints">Task 7: Glints</a>
#             </li>
#         </ul>
#     </div>
# </article>
#
#
#
# </div>
#
# ## Overview
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
# **Note:** The location of the _fovea_ on the retina varies between people ($\pm$ 5 degrees). Consequently, a gaze model has to be trained (calibrated) for a specific person to be accurate. This difference is shown in [Figure 1](#kappa).
#
# In this exercise you will implement a regression model to estimate where a person is looking (this is known as _gaze_). Gaze estimation is performed by capturing images of a user's eye as shown in [Figure 2](#model) and mapping them to screen positions using a function $f_\mathbf{w}(x, y)$. Humans look at things by orienting their eyes so that the light from the point of focus hits the _Fovea_ (a point on the retina). The Fovea is not located directly behind the pupil, but at a person-specific angle, as shown in [Figure 1](#kappa). The pupil position can be used to infer gaze, but to obtain accurate gaze estimates requires training data (called calibration).
#
#
# </div>
#
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
# <div style="float: left; width: 50%; justify-content: start" class="block is-clearfix">
#
# <div class="has-text-centered">
# <figure class="image is-inline-block" id="kappa">
#
# <img src="data:image/png;base64,..." class="figure-img img-fluid rounded" style="width:400px" />
#
# <figcaption class="figure-caption has-text-left">Figure 1: Shows the distinction between the visual and optical axes. The optical axis is defined as an axis perpendicular to the lens behind the pupil. The visual axis is personally dependent and is determined by the placement of the _fovea_.
# </figcaption>
# </figure>
# </div>
#
#
# </div>
#
# <div style="float: right; width: 50%; justify-content: start" class="block is-clearfix">
#
# <div class="has-text-centered">
# <figure class="image is-inline-block" id="model">
#
# <img src="data:image/png;base64,..." class="figure-img img-fluid rounded" style="width:400px" />
#
# <figcaption class="figure-caption has-text-centered">Figure 2: Diagram of a gaze estimation system. The eye, which is directed at a specific point on
# the screen is captured by the camera. The two red lines represent an unknown transformation from image
# to eye and eye to screen. We learn this transformation directly which is shown as $f_{\mathbf{w} }(x, y)$ in the diagram.
# </figcaption>
# </figure>
# </div>
#
#
# </div>
#
#
#
# </div>
#
# ### Gaze mapping function
# The goal of this exercise is to estimate the gaze of image sequences using a regression model. Define $f_{\mathbf{w}}(x, y)$ as the gaze  model which maps pupil positions $(x, y)$ to screen coordinates $(x', y')$. The model parameters $\mathbf{w}$ are learned using a set of paired pupil and screen positions.
# ### About data
# We provide a dataset of training and test data. The data has been captured by asking a participant to look at a specific point on a screen while capturing eye images. The pupil shape is detected for each image using ellipse approximation. The ellipses are parametrised by five parameters, `cx, cy, ax, ay, angle`
# . The center of the ellipse is assumed to be the center of the pupil.
# Each image sequence contains 9 images for calibration and a varying number of images for testing. The calibration samples always represent the same 9 screen positions which form a simple 3 by 3 grid. An example of calibration images are shown in [Figure 3](#calibration). For each sequence, you will use the 9 calibration samples to train a regression model and then use the model
# to predict gaze positions for the rest of the images.
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
# <div class="has-text-centered">
# <figure class="image is-inline-block" id="calibration">
#
# <img src="data:image/png;base64,..." class="figure-img img-fluid rounded" style="width:500px" />
#
# <figcaption class="figure-caption has-text-centered">Figure 3: Calibration images. All image sequences contain 9 calibration images
# which all have equivalent gaze positions.</figcaption>
# </figure>
# </div>
#
#
# </div>
#
# **Note:** The real notebook (the one in the materials repository) contains some extra utility code that has been hidden here for brevity. The code is fully commented and we recommend you read it whenever you are in doubt about what is happening.

# %%
import os
import json
import numpy as np
from matplotlib.patches import Ellipse
from skimage import io

import matplotlib.pyplot as plt

# %%
def load_json(folder, filename):
    """Load json file from subdirectory in "inputs/images" with the given filename
    - without .json extension!

    Returns: The json data as a dictionary or array (depending on the file).
    """
    with open(os.path.join(os.path.abspath('data/gaze/' + folder), f'{filename}.json')) as file:
        data = json.load(file)
        return data

def create_pupil_data(json_input):
    raw = [[line["cx"], line["cy"], line["ax"], line["ay"], line["angle"]] for line in json_input]
    return np.array(raw)

def create_position_data(json_input):
    raw = np.array(json_input)[:, [1, 0]]
    return np.array(raw)

def create_glint_data(json_input):
    return np.array(json_input)
   
def center_crop(img, size):
    width, height = size
    i_height, i_width = img.shape[:2]

    dy = (i_height-height)//2
    dx = (i_width-width)//2

    return img[dy: i_height-dy, dx: i_width-dx], (dx, dy)

# %%
def open_img(path, idx):
    """Open a single image from the provided path. The index specifies the image name."""
    img = io.imread(path + f'/{idx}.jpg')
    if img is None:
        raise IOError("Could not read image")
    return img

def show_example_features(dataset):
    """Draw a grid of images with the predicted pupils drawn on top."""
    images = dataset["images_test"]
    pupils = dataset["pupils_test"]
    if dataset.get("glints_test") is not None:
        glints = dataset["glints_test"]
    else:
        glints = None
        
    n = len(images)
    cols = 8
    rows = n//8+1

    fig, ax = plt.subplots(rows, cols, figsize=(cols*2, rows*2))
    for i, d in enumerate(images):
        img = d.copy()
        row = pupils[i]
        cropped, (dx, dy) = center_crop(img, (250, 250))
        ax[i//cols, i%cols].imshow(cropped)
        ellipse = Ellipse((row[0]-dx, row[1]-dy), width=row[2], height=row[3], angle=row[4], edgecolor="r", fill=None, linewidth=2)
        ax[i//cols, i%cols].add_patch(ellipse)
        
        if glints is not None:
            gs = glints[i]
            xs = gs[:, 0] - dx
            ys = gs[:, 1] - dy
            ax[i//cols, i%cols].scatter(xs, ys, marker="x")
            # for g in gs:
            #     img = cv.drawMarker(img, (int(g[0]), int(g[1])), (0, 255, 0), cv.MARKER_CROSS, 20, 3)
        
    for row in ax:
        for a in row:
            a.get_xaxis().set_visible(False)
            a.get_yaxis().set_visible(False)
    plt.show()
    
def plot_positions(data):
    """Scatter plot of the points in data"""
    plt.scatter(data[:, 0], data[:, 1])

# %% [markdown]
# ## Data and visualization
# The data for the assignment consists of 4 datasets $\mathcal{D}_{p0}, \mathcal{D}_{p1}, \mathcal{D}_{p2}, \mathcal{D}_{p3}$ where each correspond to a single recording session. The sources for each dataset are found in the subfolders of the `data/gaze`
#  folder.
# Let's get familiar with the data by visualising it.
# The code below loads each dataset $\mathcal{D}_i$ . The `show_example_features`
#  function then plots a grid of all the images from one of the datasets.
#
# ---
# **Task 1 (easy): Visualisation 1👩‍💻**
# 1. Test the visualisation for different datasets (by changing the array index when accessing images, positions, or pupils).
#
#
# ---

# %%
# Enter dataset folder name here (any subfolder in inputs/images will do)

dataset_folders = ['0', '1', '2', '3']

D = []

for f in range(4):
    pupils = create_pupil_data(load_json(str(f), 'pupils'))
    positions= create_position_data(load_json(str(f), 'positions'))
    images = [open_img(os.path.abspath('data/gaze/' + str(f)), i) for i in range(len(positions)-1)]
    D.append({
        "pupils_train": pupils[:9],
        "pupils_test": pupils[9:],
        "positions_train": positions[:9],
        "positions_test": positions[9:],
        "images_train": images[:9],
        "images_test": images[9:],
    })

# %% [markdown]
# **Details about the data format**
# Each dataset $\mathcal{D}_i$, or `D[i]`
#  in code, contains a dictionary of training and test data.
# The dataframes each contain a number of columns. Here's a description of what data each column contains.
# **Dataset elements:**
# - `pupils_train`
# : Detected pupil positions for the 9 calibration images.
# - `pupils_test`
# : Detected pupil positions for the test images.
# - `positions_train`
# : Screen target positions for the 9 calibration images.
# - `positions_test`
# : Screen target positions for the test images.
# - `images_train`
# : 9 calibration images.
# - `images_test`
# : Test images.
#
# **Array content:**
# The _pupil_ data is stored in $N\times 5$ arrays where $N$ is the number of pupils. Each row contains the five ellipse parameters for the pupil as described above. The _positions_ data is stored in $N\times 2$ arrays where each row is the $x, y$ position of the gaze target.

# %%
show_example_features(D[2])

# %% [markdown]
# ### Visualization of dataset
# Each subject in the dataset was instructed to look at a red dot on the screen while the camera captured each image.
# The cell below visualizes the recorded gaze positions on the screen.

# %%
plot_positions(D[3]["positions_test"])

#0: Even spaced grid

#1: Even spaced circle

#2: Random positions

#3: Straight line

# %% [markdown]
# ---
# **Task 2 (easy): Visualisation 2👩‍💻💡**
# The following tasks intend to help you understand how the pupil and screen positions are related visually.
# 1. Modify `idx`
#  in the cell above to visualize the screen positions for the different test sets.
# 2. Plot the detected pupil positions for the corresponding dataset in the cell below using the same method but replacing `positions_test`
#  with `pupils_test`
# .
# 3. Explain at least two possible reasons for the observed disparity between the shapes of the plotted pupil positions and the plotted screen positions.
#
# ANSWER:
# -Noise, such as camera shaking.
# -Our image transformation from image to coordinates is non-perfect
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axes = plt.subplots(4, 2, figsize=(12, 18))  # 4 rows, 2 columns

for i in range(4):  # Looping through indices 0, 1, 2, 3
    # First scatter plot for positions_test
    sns.scatterplot(x=D[i]["positions_test"][:, 0], y=D[i]["positions_test"][:, 1], ax=axes[i, 0])
    axes[i, 0].set_title(f'Positions Test - Index {i}')

    # Second scatter plot for pupils_test
    sns.scatterplot(x=D[i]["pupils_test"][:, 0], y=D[i]["pupils_test"][:, 1], ax=axes[i, 1])
    axes[i, 1].set_title(f'Pupils Test - Index {i}')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Implement a gaze estimation model
# <div style="float: none; width: 100%; justify-content: start" class="block is-clearfix">
#
# <div style="float: right; width: 25%; justify-content: start" class="block is-clearfix">
#
# <div class="has-text-centered">
# <figure class="image is-inline-block" id="gaze">
#
# <img src="data:image/png;base64,..." class="figure-img img-fluid rounded" style="width:150px" />
#
# <figcaption class="figure-caption has-text-centered">Figure 4: Point mapping. (top) Three points in screen coordinates. (middle) screen and eye $x$ coordinates for the same three points. (bottom) screen and eye $y$ coordinates for the same points.
# </figcaption>
# </figure>
# </div>
#
#
# </div>
#
# <div style="float: left; width: 75%; justify-content: start" class="block is-clearfix">
#
# The true nature of the function that converts pupil positions to screen positions is not easy to model. Even when the head is stationary, the relationship between pupil position in the image and gaze is non-linear due to the pupil's movement along a spherical curve. For now, we'll approximate the gaze mapping by using a linear function. Since this function produces two outputs—an $x'$ and a $y'$ coordinate—it's more straightforward to train separate models for each coordinate and by following the pattern of previous exercises. The linear gaze model can be expressed more as:
#
# $$
# \begin{aligned}
# x' &= ax + by + c\\
# y' &= dx + ey + f.
# \end{aligned}
# $$
# Gaze mappings is demonstrated in [Figure 4](#gaze) to the right. Here, the $x$ coordinate of the pupil maps to the $x$ coordinate on the screen. In the real model, we use both $x$ and $y$ as inputs to both the models estimating the $x$ position  and $y$ position on the screen.
#
# **Hint**
# Use the previous exercise
#  as a guideline.
#
#
# ---
# **Task 3 (easy): Identify the design matrix♾️**
# 1. ✏️ In the upcoming steps, you will be guided through the process of identifying essential entities necessary for establishing the linear equations required to learn the model parameters of the given model. The gaze model is divided into two distinct regression models, denoted as $x' = f_{w_1}(x, y)$ and $y' = f_{w_2}(x, y)$, each associated with its unique set of model parameters $w_1$ and $w_2$. Essentially, one model predicts the value of $x'$, and the other model predicts the value of $y'$. Follow the steps outlined below initially for the model $x' = f_{w_1}(x, y) = ax + by + c$, and subsequently, replicate the same steps for $y'$.
#     - Identify model parameters and inputs to the model
#     - Isolate the model parameters from a single input-output relation  using an inner product
#     - Setup the linear equations $Aw=b$, where $A$ is the design matrix, $w$ the model parameters and $b$ contains labels
#     - Identify and determine the minimim number of parameters needed to fit the model.
#
#
#
#
# ---
# ---
# **Task 4 (medium): Implement a gaze model👩‍💻♾️**
# 1. 🖥️ **Implement the design matrix:** Implement a function for generating a design matrix from pupil positions.
#
# 2. 🖥️ **Calibration:** Learn the parameters $\mathbf{w}$ for each dataset $\mathcal{D}_i$. Use the `pupils_train`
#  and `positions_train`
#  arrays as training data. Create a design matrix from the pupil positions. Use _two_ linear models, as described above, one to learn the X-coordinates and one to learn the Y-coordinates.
#
#
# **Note:** This is possibly the most difficult part of the exercise. Try to use what you learned in the two non-mandatory exercises Experimenting with the tutorial
#  and Polynomial regression
#  and apply it here. Remember that you need to fit two separate models, one for each screen coordinate.
#
# 3. 🖥️ **Estimation:** Implement a function which predicts the gaze point given a pupil position using the learned models. For reference, the linear model has the form $f_\mathbf{w}(x)=\mathbf{w}_0 x_0 + \mathbf{w}_1 x_1 + \mathbf{w}_2$. You may calculate the point for each coordinate seperately. Then calculate and return the estimated screen coordinates using the models created during calibration.
#
# **Note:** **Important!** Don't expect the linear model to perform particularly well. Expect the distances between true and predicted gaze points to vary by $\pm 200$ pixels.
#
#
# ---
#
# </div>
#
#
#
# </div>

# %%
import numpy as np

# Task 4.1: Implement the design matrix

# Function to create the design matrix and calculate weights for a dataset
def calculate_weights(pupils_train, positions_train):
    # Design matrix for both X and Y predictions
    A_design_matrix = np.array([[x[0], x[1], 1] for x in pupils_train])

    # Output for X coordinates
    output_X = np.array([[pos[0]] for pos in positions_train])

    # Output for Y coordinates
    output_Y = np.array([[pos[1]] for pos in positions_train])

    # Calculate weights for X (solving for [a, b, c] in the equation: ax + by + c = X)
    weights_X = np.linalg.inv(A_design_matrix.T @ A_design_matrix) @ A_design_matrix.T @ output_X

    # Calculate weights for Y (solving for [d, e, f] in the equation: dx + ey + f = Y)
    weights_Y = np.linalg.inv(A_design_matrix.T @ A_design_matrix) @ A_design_matrix.T @ output_Y

    return weights_X, weights_Y


# Task 4.2: Calibration
# Function to process all datasets (D[0] to D[3]) and compute weights for each
def calibration_all_datasets(D):
    weights_list = []
    
    for i in range(4):  # Loop through datasets D[0] to D[3]
        print(f"Processing dataset D[{i}]...")
        
        # Get the training data for pupils and positions
        pupils_train = D[i]["pupils_train"]
        positions_train = D[i]["positions_train"]
        
        # Calculate weights for X and Y for this dataset
        weights_X, weights_Y = calculate_weights(pupils_train, positions_train)
        
        # Append the weights for this dataset as a tuple (weights_X, weights_Y)
        weights_list.append((weights_X, weights_Y))
    
    return weights_list


# Task 4.3: Estimation
# Function to predict gaze point using the learned weights
def estimation_gaze_point(pupil_position, weights_X, weights_Y):
    design_vector = np.array([pupil_position[0], pupil_position[1], 1])
    
    # Predict X and Y coordinates
    predicted_X = design_vector @ weights_X
    predicted_Y = design_vector @ weights_Y
    
    return predicted_X[0], predicted_Y[0]


# Process all datasets and compute weights
# Here we process all datasets from D[0] to D[3] and return the results
weights_datasets = calibration_all_datasets(D)

# Task 4.3 Example: Predict gaze point using the learned weights
# Now that we have learned the weights, we can use the prediction function
# Example: predict the gaze point for the first pupil position in D[0]
test_pupil_position_D0 = D[0]["pupils_train"][0]
weights_D0_X, weights_D0_Y = weights_datasets[0]

predicted_gaze_D0 = estimation_gaze_point(test_pupil_position_D0, weights_D0_X, weights_D0_Y)
print(f"Predicted gaze point for D[0] first pupil position: {predicted_gaze_D0}")

# Accessing weights for datasets:

# For D[0]
weights_D0_X, weights_D0_Y = weights_datasets[0]
print("Weights for D[0] X:", weights_D0_X)
print("Weights for D[0] Y:", weights_D0_Y)

# For D[1]
weights_D1_X, weights_D1_Y = weights_datasets[1]
print("Weights for D[1] X:", weights_D1_X)
print("Weights for D[1] Y:", weights_D1_Y)

# For D[2]
weights_D2_X, weights_D2_Y = weights_datasets[2]
print("Weights for D[2] X:", weights_D2_X)
print("Weights for D[2] Y:", weights_D2_Y)

# For D[3]
weights_D3_X, weights_D3_Y = weights_datasets[3]
print("Weights for D[3] X:", weights_D3_X)
print("Weights for D[3] Y:", weights_D3_Y)

def show_gaze_difference(D, weights_results):
    for i in range(4):  # Loop through datasets D[0] to D[3]
        print(f"\nDataset D[{i}] comparison:")
        
        pupils_train = D[i]["pupils_train"]
        true_positions = D[i]["positions_train"]
        weights_X, weights_Y = weights_results[i]
        
        # Iterate over each pupil position and calculate the estimated gaze point
        for idx, pupil_position in enumerate(pupils_train):
            true_gaze = true_positions[idx]
            estimated_gaze = estimation_gaze_point(pupil_position, weights_X, weights_Y)
            
            # Calculate the difference between true and estimated gaze points
            difference = np.array(true_gaze) - np.array(estimated_gaze)
            
            # Display the true, estimated, and difference
            print(f"Index {idx}: True Gaze = {true_gaze}, Estimated Gaze = {estimated_gaze}, Difference = {difference}")

# Example: Show the differences for all datasets
show_gaze_difference(D, weights_datasets)
# Out:
# Processing dataset D[0]...
# Processing dataset D[1]...
# Processing dataset D[2]...
# Processing dataset D[3]...
# Predicted gaze point for D[0] first pupil position: (-24.07658905471726, 96.52817631992275)
# Weights for D[0] X: [[-2.78430276e+01]
#  [-7.27880927e-01]
#  [ 9.57251528e+03]]
# Weights for D[0] Y: [[ 1.71684820e+00]
#  [ 2.74875054e+01]
#  [-5.90180720e+03]]
# Weights for D[1] X: [[-2.63330155e+01]
#  [ 4.25690623e-02]
#  [ 8.90741780e+03]]
# Weights for D[1] Y: [[ 9.66057022e-01]
#  [ 2.84780881e+01]
#  [-6.06857430e+03]]
# Weights for D[2] X: [[-2.82745018e+01]
#  [ 5.37213983e-01]
#  [ 9.43269441e+03]]
# Weights for D[2] Y: [[ 1.71740484e+00]
#  [ 2.79702804e+01]
#  [-6.19010379e+03]]
# Weights for D[3] X: [[-2.65908145e+01]
#  [-1.59170020e+00]
#  [ 9.12762516e+03]]
# Weights for D[3] Y: [[ 8.52911707e-01]
#  [ 2.88818605e+01]
#  [-5.91374794e+03]]
#
# Dataset D[0] comparison:
# Index 0: True Gaze = [50 50], Estimated Gaze = (-24.07658905471726, 96.52817631992275), Difference = [ 74.07658905 -46.52817632]
# Index 1: True Gaze = [960  50], Estimated Gaze = (992.887566413985, -86.29169764363814), Difference = [-32.88756641 136.29169764]
# Index 2: True Gaze = [1870   50], Estimated Gaze = (1865.9692974886184, 121.45897422412872), Difference = [  4.03070251 -71.45897422]
# Index 3: True Gaze = [ 50 540], Estimated Gaze = (20.991747573825705, 601.6985877574853), Difference = [ 29.00825243 -61.69858776]
# Index 4: True Gaze = [960 540], Estimated Gaze = (1084.9949204648474, 555.6388656925283), Difference = [-124.99492046  -15.63886569]
# Index 5: True Gaze = [1870  540], Estimated Gaze = (1845.3054315432328, 567.2888961345798), Difference = [ 24.69456846 -27.28889613]
# Index 6: True Gaze = [  50 1030], Estimated Gaze = (61.576629160847006, 992.3463015847592), Difference = [-11.57662916  37.65369842]
# Index 7: True Gaze = [ 960 1030], Estimated Gaze = (1029.0199080376497, 999.196588699363), Difference = [-69.01990804  30.8034113 ]
# Index 8: True Gaze = [1870 1030], Estimated Gaze = (1763.331088371482, 1012.1353072307511), Difference = [106.66891163  17.86469277]
#
# Dataset D[1] comparison:
# Index 0: True Gaze = [50 50], Estimated Gaze = (-44.867553767389836, 72.59683826340188), Difference = [ 94.86755377 -22.59683826]
# Index 1: True Gaze = [960  50], Estimated Gaze = (1033.6197099781448, 0.021735023102337436), Difference = [-73.61970998  49.97826498]
# Index 2: True Gaze = [1870   50], Estimated Gaze = (1868.996918007193, 53.18037904323137), Difference = [ 1.00308199 -3.18037904]
# Index 3: True Gaze = [ 50 540], Estimated Gaze = (27.855501913396438, 574.4223344162947), Difference = [ 22.14449809 -34.42233442]
# Index 4: True Gaze = [960 540], Estimated Gaze = (1052.1864487847415, 514.3361496748348), Difference = [-92.18644878  25.66385033]
# Index 5: True Gaze = [1870  540], Estimated Gaze = (1818.715481748497, 597.6736755654429), Difference = [ 51.28451825 -57.67367557]
# Index 6: True Gaze = [  50 1030], Estimated Gaze = (69.6081139333055, 1011.4296571155792), Difference = [-19.60811393  18.57034288]
# Index 7: True Gaze = [ 960 1030], Estimated Gaze = (1032.413910409754, 1014.8820761867255), Difference = [-72.41391041  15.11792381]
# Index 8: True Gaze = [1870 1030], Estimated Gaze = (1781.4714689928023, 1021.4571547115611), Difference = [88.52853101  8.54284529]
#
# Dataset D[2] comparison:
# Index 0: True Gaze = [50 50], Estimated Gaze = (-33.23003590950793, 55.721995328205594), Difference = [83.23003591 -5.72199533]
# Index 1: True Gaze = [960  50], Estimated Gaze = (1045.6901252533535, -20.088821844822633), Difference = [-85.69012525  70.08882184]
# Index 2: True Gaze = [1870   50], Estimated Gaze = (1848.0860820750886, 93.94750254969131), Difference = [ 21.91391792 -43.94750255]
# Index 3: True Gaze = [ 50 540], Estimated Gaze = (21.063105266177445, 593.8085496467302), Difference = [ 28.93689473 -53.80854965]
# Index 4: True Gaze = [960 540], Estimated Gaze = (1041.129192799308, 513.9082431391471), Difference = [-81.1291928   26.09175686]
# Index 5: True Gaze = [1870  540], Estimated Gaze = (1836.6969416258744, 580.4408212780781), Difference = [ 33.30305837 -40.44082128]
# Index 6: True Gaze = [  50 1030], Estimated Gaze = (60.42071216867407, 1012.5691538703886), Difference = [-10.42071217  17.43084613]
# Index 7: True Gaze = [ 960 1030], Estimated Gaze = (1037.279778994418, 1031.2020331460526), Difference = [-77.27977899  -1.20203315]
# Index 8: True Gaze = [1870 1030], Estimated Gaze = (1782.8640977267141, 998.4905228865518), Difference = [87.13590227 31.50947711]
#
# Dataset D[3] comparison:
# Index 0: True Gaze = [50 50], Estimated Gaze = (-56.41174998687711, 87.13790157406766), Difference = [106.41174999 -37.13790157]
# Index 1: True Gaze = [960  50], Estimated Gaze = (1038.398818755526, 10.456563338080741), Difference = [-78.39881876  39.54343666]
# Index 2: True Gaze = [1870   50], Estimated Gaze = (1856.0845324884976, 44.825725160186266), Difference = [13.91546751  5.17427484]
# Index 3: True Gaze = [ 50 540], Estimated Gaze = (31.59278290023758, 567.2324396021304), Difference = [ 18.4072171 -27.2324396]
# Index 4: True Gaze = [960 540], Estimated Gaze = (1074.8419919519329, 509.40727036841054), Difference = [-114.84199195   30.59272963]
# Index 5: True Gaze = [1870  540], Estimated Gaze = (1821.7269116984571, 574.6978353652376), Difference = [ 48.2730883  -34.69783537]
# Index 6: True Gaze = [  50 1030], Estimated Gaze = (70.35772214593271, 1003.4759308955063), Difference = [-20.35772215  26.5240691 ]
# Index 7: True Gaze = [ 960 1030], Estimated Gaze = (1027.8248357429065, 1005.2231778004752), Difference = [-67.82483574  24.7768222 ]
# Index 8: True Gaze = [1870 1030], Estimated Gaze = (1775.5841543034476, 1057.5431558959608), Difference = [ 94.4158457 -27.5431559]

# %% [markdown]
# ## Evaluation of the regression model

# %%
# Write your solution here
#Solved above...

# %% [markdown]
# ---
# **Task 5 (medium): Model evaluation👩‍💻💡**
# In the following you have to evaluate the performance of your models. Each individual task should be repeated for all datasets ($\mathcal{D}_{0}, \mathcal{D}_{1}, \mathcal{D}_{2}, \mathcal{D}_{3}$). It is important that the results are calculated for all datasets simultaneously because you have to use the results later in the assignment.
# 1. 🖥️ **Calculate errors:**
#     - Predict gaze positions for the test pupils in `pupils_test`
# .
#     - Calculate the _root-mean-square error_ (_rmse_) between the true values in `positions_test`
#  and the predictions.
#     - Calculate the _mean absolute error_ (_mae_) as well.
#
#
# 2. 🖥️ **Create visualizations:**:
#     - Make a scatterplot of the predicted positions and ground-truth positions. You may use the `plot_results`
#  function provided below.
#     - Make a scatterplot of the errors ($x$ against $y$) using the `plot_positions`
#  function. This should give you an overview of how the errors are distributed.
#
#
# 3. 🖥️ **Evaluate:**
#     - Determine whether the _mae_ or _rmse_ is most useful for evaluating the precision of the gaze models. Explain your answer.
#     - Identify at least 3 potential sources of error associated with the current linear model. Describe how each source of error contributes to the prediction error.
#
#
#
#
# ---

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def plot_results(predicted, ground_truth):
    """Plot prediction results with numbers and arrows indicating prediction/ground_truth 
    pairs.
    
    Args:
        predicted: Nx2 array of predicted points. 
        ground_truth: Nx2 array of ground_truth points.
    """
    fig, ax = plt.subplots(1, 1)
    
    dx = predicted[:, 0] - ground_truth[:, 0]
    dy = predicted[:, 1] - ground_truth[:, 1]
    ax.quiver(ground_truth[:, 0], ground_truth[:, 1], dx, dy, scale=1, angles='xy', scale_units='xy')
    
    ax.scatter(predicted[:, 0], predicted[:, 1], label="Prediction")
    ax.scatter(ground_truth[:, 0], ground_truth[:, 1], label="Ground truth")
    
    for i in range(predicted.shape[0]):
        ax.annotate(i, (predicted[i, 0], predicted[i, 1]))
        ax.annotate(i, (ground_truth[i, 0], ground_truth[i, 1]))
    
    plt.legend()
    plt.title('Ground truth and predictions')
    plt.show()

# Write your evaluation code here

# Task 5.1: Calculate errors (RMSE and MAE)
def calculate_errors(D, weights_results):
    for i in range(4):  # Loop through datasets D[0] to D[3]
        print(f"\nDataset D[{i}] error calculations:")
        
        # Get test data
        pupils_test = D[i]["pupils_test"]
        true_positions_test = D[i]["positions_test"]
        weights_X, weights_Y = weights_results[i]

        # Predict gaze positions for test data
        predicted_gaze_points = np.array([estimation_gaze_point(pupil, weights_X, weights_Y) for pupil in pupils_test])

        # Calculate RMSE
        rmse = np.sqrt(mean_squared_error(true_positions_test, predicted_gaze_points))
        print(f"RMSE for D[{i}]: {rmse:.2f}")

        # Calculate MAE
        mae = mean_absolute_error(true_positions_test, predicted_gaze_points)
        print(f"MAE for D[{i}]: {mae:.2f}")

        # Visualization: Plot predictions vs ground truth
        plot_results(predicted_gaze_points, np.array(true_positions_test))


# Task 5.3: Evaluate model performance
def evaluate_model():
    print("Evaluating whether RMSE or MAE is more useful for the gaze model.")
    print("Possible sources of error in the current linear model:")
    print("1. The linear model may not capture the non-linear relationships between pupil positions and gaze points.")
    print("2. Errors may occur due to noisy or inconsistent pupil tracking data.")
    print("3. Outliers in the training or test data could affect the performance of the model.")
    print("4. Calibration inconsistencies or variations across datasets may introduce error.")

# Now, we'll run the calculations on the datasets
weights_results = calibration_all_datasets(D)
calculate_errors(D, weights_results)
evaluate_model()
# Out:
# Processing dataset D[0]...
# Processing dataset D[1]...
# Processing dataset D[2]...
# Processing dataset D[3]...
#
# Dataset D[0] error calculations:
# RMSE for D[0]: 126.85
# MAE for D[0]: 104.66
# Dataset D[1] error calculations:
# RMSE for D[1]: 98.95
# MAE for D[1]: 88.01
# Dataset D[2] error calculations:
# RMSE for D[2]: 72.92
# MAE for D[2]: 61.07
# Dataset D[3] error calculations:
# RMSE for D[3]: 94.84
# MAE for D[3]: 77.55
# Evaluating whether RMSE or MAE is more useful for the gaze model.
# Possible sources of error in the current linear model:
# 1. The linear model may not capture the non-linear relationships between pupil positions and gaze points.
# 2. Errors may occur due to noisy or inconsistent pupil tracking data.
# 3. Outliers in the training or test data could affect the performance of the model.
# 4. Calibration inconsistencies or variations across datasets may introduce error.

# %% [markdown]
# ## Improve the model
# This final part of the exercise requires you to modify  the gaze model $f_{\mathbf{w}}(x,y)$ into a quadratic model. As in [Task 4](#task_model), you will create a model for each output coordinate, i.e. $x', y'$.
# **Note:** In this step you create one model for each output coordinate seperately but it is possible to create a single model that simultaneously maps the $x'$- and $y'$-coordinates. However, we leave it as an optional exercise for you to figure out how to do this. Hint: You have to combine the design and parameter matrices.
#
# Since the model is two-dimensional, the quadratic polynomial has  more model parameters than for one dimension model. The equation for each axis is:
#
# $$
# f(x, y) = a\cdot x^2 + b\cdot y^2 + c\cdot xy + d\cdot x + e\cdot y + f.
# $$
# The design matrices then have the following form:
#
# ---
# **Task 6 (medium): Model improvements👩‍💻💡**
# 1. ✏️  **Design matrix:**
# Argue why the desginmatrix for each output coordinate of the gaze mapping function is given by
#
# $$
# D_x = D_y = \begin{bmatrix}
#  		x_1^2 & y_1^2 & x_1y_1 & x_1 & y_1 & 1\\
#   		x_2^2 & y_2^2 & x_2y_2 & x_2 & y_2 & 1\\
#   		\vdots &&&&& \\
#    		x_2^2 & y_2^2 & x_ny_n & x_n & y_n & 1\\
#  	\end{bmatrix}.$$
#
#
# 2. 🖥️ **Implement model:** Implement the 2. order model and train it (calibrate) on each dataset.
#
# 3. ✏️ **Evaluate:** Repeat the evaluation steps you did for the linear model above in [Task 5](#evaluation) (subtask 1-2). Additionally:
#     - Create a barplot of the _rmse_ of both models for each dataset. Use the `bar_comparison_plot`
#  function.
#
#
# 4. 🖥️ **Compare with linear results:**
#     - Is there a significant difference between the _rmse_'s of the linear and 2. order models? Explain why either is the case. Use your previous discussion of model limitations and error sources in your explanation.
#     - Compare the scatter plots for the predictions vs. ground-truth for both models. Is there a qualitative difference in performance in some instances? Explain why either model performs better in particular cases and relate your answer to the previous question.
#
#
#
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Task 6.1: Design matrix for the quadratic model
def calculate_quadratic_weights(pupils_train, positions_train):
    # Design matrix for quadratic model: [x^2, y^2, xy, x, y, 1]
    A_design_matrix = np.array([
        [x[0]**2, x[1]**2, x[0]*x[1], x[0], x[1], 1] for x in pupils_train
    ])

    # Output for X coordinates
    output_X = np.array([[pos[0]] for pos in positions_train])

    # Output for Y coordinates
    output_Y = np.array([[pos[1]] for pos in positions_train])

    # Calculate weights for X (solving for [a, b, c, d, e, f] in the quadratic model)
    weights_X = np.linalg.inv(A_design_matrix.T @ A_design_matrix) @ A_design_matrix.T @ output_X

    # Calculate weights for Y
    weights_Y = np.linalg.inv(A_design_matrix.T @ A_design_matrix) @ A_design_matrix.T @ output_Y

    return weights_X, weights_Y

# Task 6.2: Implement quadratic model
def process_all_datasets_quadratic(D):
    weights_list = []
    
    for i in range(4):  # Loop through datasets D[0] to D[3]
        print(f"Processing dataset D[{i}] for quadratic model...")
        
        pupils_train = D[i]["pupils_train"]
        positions_train = D[i]["positions_train"]
        
        # Calculate weights for X and Y for this dataset using quadratic design matrix
        weights_X, weights_Y = calculate_quadratic_weights(pupils_train, positions_train)
        
        weights_list.append((weights_X, weights_Y))
    
    return weights_list

# Task 6.3: Evaluate both linear and quadratic models
def evaluate_models(D, weights_linear, weights_quadratic):
    rmses_linear = []
    rmses_quadratic = []
    
    for i in range(4):  # Loop through datasets D[0] to D[3]
        pupils_test = D[i]["pupils_test"]
        true_positions_test = D[i]["positions_test"]

        # Predict gaze positions for linear model
        weights_X_lin, weights_Y_lin = weights_linear[i]
        predicted_gaze_linear = np.array([estimation_gaze_point(pupil, weights_X_lin, weights_Y_lin) for pupil in pupils_test])

        # Predict gaze positions for quadratic model
        weights_X_quad, weights_Y_quad = weights_quadratic[i]
        predicted_gaze_quadratic = np.array([predict_gaze_point_quadratic(pupil, weights_X_quad, weights_Y_quad) for pupil in pupils_test])

        # Calculate RMSE for linear and quadratic models
        rmse_linear = np.sqrt(mean_squared_error(true_positions_test, predicted_gaze_linear))
        rmse_quadratic = np.sqrt(mean_squared_error(true_positions_test, predicted_gaze_quadratic))
        
        rmses_linear.append(rmse_linear)
        rmses_quadratic.append(rmse_quadratic)

        print(f"Dataset D[{i}] - Linear RMSE: {rmse_linear:.2f}, Quadratic RMSE: {rmse_quadratic:.2f}")

    return rmses_linear, rmses_quadratic

# Task 6.4: Compare models using bar plot
def bar_comparison_plot(rmses_linear, rmses_quad):
    """Draw a bar chart comparing two sets of RMS errors.
    
    Args:
        rmses_linear: Results from the linear model.
        rmses_quad: Results from the quadratic model.
    """
    width = 0.3
    datasets = ["p0", "p1", "p2", "p3"]
    bx = np.arange(len(datasets))
    plt.bar(bx, rmses_linear, width, label="Linear") 
    plt.bar(bx + width, rmses_quad, width, label="Quadratic") 
    plt.xticks(bx + width/2, datasets)
    plt.title("RMSE for the linear and quadratic model")
    plt.legend()
    plt.show()


# Helper function for quadratic prediction
def predict_gaze_point_quadratic(pupil_position, weights_X, weights_Y):
    design_vector = np.array([pupil_position[0]**2, pupil_position[1]**2, pupil_position[0]*pupil_position[1], pupil_position[0], pupil_position[1], 1])
    
    predicted_X = design_vector @ weights_X
    predicted_Y = design_vector @ weights_Y
    
    return predicted_X[0], predicted_Y[0]

# Process both linear and quadratic models
weights_linear = calibration_all_datasets(D)  # This uses the linear model from Task 4
weights_quadratic = process_all_datasets_quadratic(D)  # This is for the quadratic model

# Evaluate and compare both models
rmses_linear, rmses_quadratic = evaluate_models(D, weights_linear, weights_quadratic)

# Plot comparison of RMSEs for linear and quadratic models
bar_comparison_plot(rmses_linear, rmses_quadratic)
# Out:
# Processing dataset D[0]...
# Processing dataset D[1]...
# Processing dataset D[2]...
# Processing dataset D[3]...
# Processing dataset D[0] for quadratic model...
# Processing dataset D[1] for quadratic model...
# Processing dataset D[2] for quadratic model...
# Processing dataset D[3] for quadratic model...
# Dataset D[0] - Linear RMSE: 126.85, Quadratic RMSE: 110.43
# Dataset D[1] - Linear RMSE: 98.95, Quadratic RMSE: 65.86
# Dataset D[2] - Linear RMSE: 72.92, Quadratic RMSE: 68.12
# Dataset D[3] - Linear RMSE: 94.84, Quadratic RMSE: 97.25

# %% [markdown]
# ## Accounting for head movements (optional)
#
# **Info**
# The following tasks are optional but should give you significantly better gaze estimation results. You should not attempt to solve this exercise before finishing the mandatory parts of the assignment. You are also welcome to hand in the optional part if you want to get feedback on your solution.
#
# In this exercise you will implement a method that improves your gaze estimation model using _glints_. A glint is the reflection of a light-source on the surface of the eye and is usually created using LEDs. You may have noticed that glints are already present in the provided images, otherwise check [Figure 3](#calibration). Glints are used to derive a vector for the pupil position that is independent of the eyes location in the image. This is particularly useful for situations where the participant move the head. If we only use the pupil, any head movement will affect  the gaze prediction significantly.
# In this exercise, you will enhance your gaze estimation model by incorporating glints. Glints are reflections of light sources on the eye's surface, typically generated by LEDs. You can observe glints in the provided images; if not, refer to [Figure 3](#calibration). Glints serve to establish a vector to the pupil position that remains robust when participants move their heads. Relying solely on the pupil would make the gaze prediction susceptible to significant deviations with any head movement.
# Two additional datasets, $\mathcal{D}{4}$ and $\mathcal{D}{5}$, have been introduced for the upcoming tasks. They were each recorded with the subject moving their head while gazing at the test positions. The glints are loaded from a file, just like the pupils and gaze positions. Each image contains four glints, corresponding to four light sources, organized in an $N\times 4\times 2$ array. In other words, each image has four glints, and each glint is specified by an $x, y$ position. The code cell below loads the new data.:

# %%
# Enter dataset folder name here (any subfolder in inputs/images will do)
dataset_folders = ['0', '1', '2', '3', '4', '5']

D = []

for f in range(6):
    pupils = create_pupil_data(load_json(str(f), 'pupils'))
    positions= create_position_data(load_json(str(f), 'positions'))
    glints = create_glint_data(load_json(str(f), 'glints'))
    images = [open_img(os.path.abspath('data/gaze/' + str(f)), i) for i in range(len(positions)-1)]
    D.append({
        "pupils_train": pupils[:9],
        "pupils_test": pupils[9:],
        "glints_train": glints[:9],
        "glints_test": glints[9:],
        "positions_train": positions[:9],
        "positions_test": positions[9:],
        "images_train": images[:9],
        "images_test": images[9:],
    })

# %% [markdown]
# Run the cell below to visualize the glints in one of the datasets:

# %%
show_example_features(D[4])

# %% [markdown]
# ---
# **Task 7 (hard): Glints👩‍💻💡**
# 1. 🖥️ **Remove outliers:** The glints are not always detected reliably. This should be clear from the images above. You have to implement a method to determine whether a glint position is valid or not.
#     - Filter the glints based on their distance to the pupil center. Define a threshold for which glints will be considered outliers.
#     - Experiment with the threshold to find a value that removes most outliers. This is important for the calibration to work properly.
#
#
# 2. 🖥️ **Determine top-left glint and calculate glint-pupil vector:** For simplicity, you will only use the top-left glint in each image.
#     - Find a method to determine whether the top-left glint is visible in each image. Filter out any images where this glint isn't visible.
#     - Calculate the difference vector between the pupil and top-left glint in each image. Save the result in an array for each dataset.
#
#
# 3. 🖥️ **Calibrate models:**
#     - Train the linear and 2. order models on the difference vectors you calculated above. For some datasets, you may not be able to train the 2. order model if some of the calibration images are missing.
#
#
# 4. ✏️ **Evaluate:**
#     - Test the new models using the same method as in [Task 5](#evaluation) and [Task 6](#improvements)
#     - Compare the results using the same steps as described in [Task 6](#improvements) (if you want feedback)
#     - Try to add the $\mathcal{D}_{4}$ and $\mathcal{D}_{5}$ datasets to the original models. Compare the results with the glint-based method.
#
#
#
#
# ---

# %%
# Write your implementation here

# %% [markdown]
# **Submission**
# [For submission details click here](https://learnit.itu.dk/mod/page/view.php?id=184893)
#
# [For submitting the exercise click here](https://learnit.itu.dk/mod/assign/view.php?id=185255)
